# %%
# Load the default python JSON library
import json
import csv
import os

# This tell python to look for the JSON as a file in the directory of the python script in a read-only mode (the 'r' argument)
# Change 'filename' to the correct file path i.e. 'logs/10.txt'

#dont we need an "i" function here?

datas = []

files = [f for f in os.listdir('.') if os.path.isfile(f)]
for f in files:

    if f == '11' or f == '12':
        
        with open(f, 'r') as file:
        # Since the JSON is correctly formatter, this will just dump it into a Python dictionary
            data = json.load(file)
            datas.append(data) 

     #   contents = f.readlines() #put the lines to a variable (list).
      #  print(contents)
# Out:
# [{'date': '2017-09-26T21:00:48.938Z', 'experiment': [{'dataType': 'prompt', 'promptTitle': 'Trial Run', 'promptText': 'We would like to observe how quickly people can categorize images. In the following screens, you’ll see a series of images categorized as owls. Please select “Owl” (left) or “Not Owl” (right) as quickly and as accurately as possible. This is a trial run and no results are recorded.', 'promptImage': 'images/tutorial/tutorial_owl.jpg'}, {'dataType': 'trial', 'flag': None, 'trialImage': 'images/owl/owl5.jpg', 'trialText': 'Is this an owl?', 'mouse': [{'time': 1506459654334, 'x': 377, 'y': 421}, {'time': 1506459654334, 'x': 377, 'y': 421}, {'time': 1506459654342, 'x': 381, 'y': 414}, {'time': 1506459654342, 'x': 381, 'y': 414}, {'time': 1506459654349, 'x': 392, 'y': 396}, {'time': 1506459654349, 'x': 392, 'y': 396}, {'time': 1506459654358, 'x': 404, 'y': 374}, {'time': 1506459654358, 'x': 404, 'y': 374}, {'time': 1506459654366, 'x': 432, 'y': 324}, {'time': 1506459654366
# ...

# %%
 for trial in data["experiment"]:

    value0 = data["name"]
        
    if trial["dataType"] == "trial":

        values = []

        value1 = trial["trialImage"]
        value2 = trial["flag"]
        value3 = trial["action"]
        value4 = trial["mouse"]

        values2 = [value0 , value1 , value2 , value3 , value4]

        values.append(values2)

print(values)
# Out:
# [['steve', 'images/dog/dog1.jpg', False, 'optionB', [{'time': 1506459948957, 'x': 366, 'y': 426}, {'time': 1506459948957, 'x': 366, 'y': 426}, {'time': 1506459948965, 'x': 377, 'y': 408}, {'time': 1506459948965, 'x': 377, 'y': 408}, {'time': 1506459948973, 'x': 391, 'y': 389}, {'time': 1506459948973, 'x': 391, 'y': 389}, {'time': 1506459948981, 'x': 404, 'y': 369}, {'time': 1506459948981, 'x': 404, 'y': 369}, {'time': 1506459948990, 'x': 433, 'y': 331}, {'time': 1506459948990, 'x': 433, 'y': 331}, {'time': 1506459948998, 'x': 462, 'y': 289}, {'time': 1506459948998, 'x': 462, 'y': 289}, {'time': 1506459949006, 'x': 474, 'y': 272}, {'time': 1506459949006, 'x': 474, 'y': 272}, {'time': 1506459949014, 'x': 499, 'y': 238}, {'time': 1506459949014, 'x': 499, 'y': 238}, {'time': 1506459949022, 'x': 509, 'y': 227}, {'time': 1506459949022, 'x': 509, 'y': 227}, {'time': 1506459949030, 'x': 528, 'y': 204}, {'time': 1506459949030, 'x': 528, 'y': 204}, {'time': 1506459949038, 'x': 535, 'y': 197}, 
# ...
